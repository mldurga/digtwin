# %% [markdown]
# # APA-PI
# > Aveva Predictive Analytics DigitalTwin Library

# %% [markdown]
# # AVEVA Predictive Analytics and AVEVA PI System Integration: Template Guide
#
# ## Introduction: Overview
#
# This document provides a comprehensive guide to integrating AVEVA Predictive Analytics (APA) with the AVEVA PI System. APA serves as an anomaly detection and predictive analytics engine, utilizing machine learning. The AVEVA PI System acts as the industrial historian, storing time-series data for equipment. This guide focuses on templates within the PI Digital Twin that are part of the Predictive Analytics Library. These templates provide models for both rotating and static equipment.
#
# ## Understanding AVEVA Predictive Analytics
#
# AVEVA Predictive Analytics uses machine learning to detect anomalies in industrial equipment. It can process data from various historians, including:
#
# * PI Data Archive
# * PI Asset Framework
# * Other compatible data sources
#
# The 2023 version of APA includes an embedded archive to store prediction values and results, enabling seamless data flow:
#
# * Predictive Analytics → PI Data Archive
# * PI Data Archive → Predictive Analytics
#
# ## Purpose of This Document
#
# This document provides a set of templates for various industrial equipment types, facilitating predictive maintenance and anomaly detection. Each equipment type has unique characteristics; therefore, specific templates are necessary. These templates can be accessed and explored within the PI System Explorer.
#
# ## Template Library
#
# The following tables categorize and describe the available templates within the AVEVA Predictive Analytics Library.
#
# ### BASE Library Templates
#
# | Template Name | Description |
# |:--|:--|
# | AVV-PIDT.BAS.Master | Top-level template; contains elements included in all derived templates. Provides a foundation for all other templates. |
# | AVV-PIDT.BAS.Accessories | Optional templates that provide additional functionality, acting as child templates to a parent. Extends the capabilities of main equipment templates. |
# | AVV-PIDT.BAS.Acc.AdvancedAnalytics | Provides calculations to describe and simulate operating conditions for processes and equipment. Focuses on in-depth analytical capabilities. |
# | AVV-PIDT.BAS.Acc.AVEVA-PredictiveAnalytics | Base template specific to AVEVA Predictive Analytics integration. Establishes the core connection and data flow for APA. |
#
# ### Rotating Equipment Templates
#
# These templates are designed for equipment with rotating components, covering a wide range of drivers and driven machinery.
#
# #### Performance Templates
#
# These templates focus on identifying performance degradation.
#
# | Template Name | Description |
# |:--|:--|
# | AVV-PIDT.APA.Acc.RotEqpt.Performance | General template for assessing the performance of any rotating equipment. Provides a high-level view of operational efficiency. |
# | AVV-PIDT.APA.Acc.RotEqpt.Performance.Driven | Performance template specifically for driven rotating equipment (e.g., pumps, compressors). Focuses on the equipment being powered by a separate driver. |
# | AVV-PIDT.APA.Acc.RotEqpt.Performance.Driven.Compressor | Performance template for driven compressors. Monitors the efficiency and operational characteristics of the compressor unit. |
# | AVV-PIDT.APA.Acc.RotEqpt.Performance.Driven.Compressor.Centrifugal.Compander | Performance template for centrifugal companders (combined compressor and expander). Tracks the combined performance of both compression and expansion stages. |
# | AVV-PIDT.APA.Acc.RotEqpt.Performance.Driver | Performance template for the driving component of rotating equipment (e.g., motors, turbines). Analyzes the efficiency and output of the driver unit. |
# | AVV-PIDT.APA.Acc.RotEqpt.Performance.Driver.Expander | Performance template specifically for expanders. Monitors the performance and efficiency of the expansion process. |
# | AVV-PIDT.APA.Acc.RotEqpt.Performance.Driver.Expander.Compander | Performance template for companders from the driver (expander) perspective. Focuses on the expander's role in the combined compression/expansion process. |
# | AVV-PIDT.APA.Acc.RotEqpt.Performance.Driven.Pump.Centrifugal | Performance calculations for Centrifugal Pump. |
# | AVV-PIDT.APA.Acc.RotEqpt.Performance.Compressor.Centrifugal | Performance degradation detection capabilities for Centrifugal Compressor. |
# | AVV-PIDT.APA.Acc.RotEqpt.Performance.Compressor.IntegrallyGeared | For monitoring and loss detections in Integrally Geared Compressors. |
# | AVV-PIDT.APA.Acc.RotEqpt.Performance.Compressor.Reciprocating | This template will help us to analyze loss in performance for Reciprocating Compressors. |
# | AVV-PIDT.APA.Acc.RotEqpt.Performance.Compressor.Screw | For analyzing the Screw Compressor performance. |
# | AVV-PIDT.APA.Acc.RotEqpt.Performance.Driven.AirBlower | To Detect Performance Degradation for Air Blowers. |
# | AVV-PIDT.APA.Acc.RotEqpt.Performance.Driven.Fan | For Performance analysis of Fans. |
# | AVV-PIDT.APA.Acc.RotEqpt.Performance.Driven.GasTurbine | For Peformance Calculation of Gas Turbines. |
# | AVV-PIDT.APA.Acc.RotEqpt.Performance.Driven.Generator | Performance calculation template for Generators. |
# | AVV-PIDT.APA.Acc.RotEqpt.Performance.Driver.Motor | Performance calculations based models for Motor. |
# | AVV-PIDT.APA.Acc.RotEqpt.Performance.Driver.SteamTurbine | Performance calculations based models for Steam Turbine. |
#
# #### Rotating Equipment - Driven Templates
#
# These templates are for equipment *powered by* a separate driver.
#
# ##### Combustion Air Blower:
#
# | Template Name | Description |
# |:--|:--|
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.CombAirBlower | General template for combustion air blowers. Provides a top-level view of the blower's operation. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.CombAirBlower.Mechanical | Monitors the mechanical aspects of a combustion air blower (e.g., bearings, vibrations). Focuses on physical integrity. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.CombAirBlower.Process | Monitors the process parameters of a combustion air blower (e.g., flow, pressure). Focuses on operational performance. |
#
# ##### Compressor:
#
# | Template Name | Description |
# |:--|:--|
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Compressor | General template for driven compressors. Provides a comprehensive view of compressor operation. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Compressor.Centrifugal | Template for driven centrifugal compressors. Covers a wide range of centrifugal compressor types. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Compressor.Centrifugal.DryGasSeal | Monitors the dry gas seal system of a centrifugal compressor. Focuses on seal integrity and leakage prevention. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Compressor.Centrifugal.Mechanical | Monitors the mechanical condition of a centrifugal compressor. Assesses physical components like bearings and vibrations. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Compressor.Centrifugal.Mechanical.Canned | Specifically for canned centrifugal compressors, focusing on mechanical aspects. Addresses the unique design of canned compressors. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Compressor.Centrifugal.OilFilmSeal | Monitors the oil film seal system of a centrifugal compressor. Ensures proper lubrication and sealing. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Compressor.Centrifugal.Process | Monitors the process parameters of a centrifugal compressor. Tracks flow, pressure, temperature, and other operational variables. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Compressor.Centrifugal.Process.Canned | Process monitoring for canned centrifugal compressors. Combines process monitoring with the specific needs of canned designs. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Compressor.Centrifugal.Process.FixedSpeed | Process monitoring for fixed-speed centrifugal compressors. Optimized for constant-speed operation. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Compressor.Centrifugal.Process.VariableSpeed | Process monitoring for variable-speed centrifugal compressors. Adapts to changing speed and load conditions. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Compressor.Centrifugal.Process.WithSideStreamSuction | Process monitoring for centrifugal compressors with side stream suction. Accounts for the additional complexity of side stream flows. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Compressor.IntegrallyGeared | Template for driven integrally geared compressors. Addresses the specific design and operational characteristics of this compressor type. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Compressor.IntegrallyGeared.Mechanical | Mechanical monitoring for integrally geared compressors. Focuses on the gearbox and other mechanical components. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Compressor.IntegrallyGeared.7STG.Mechanical | Specifically for 7-stage integrally geared compressors, mechanical monitoring. Tailored to the multi-stage design. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Compressor.IntegrallyGeared.Process | Process monitoring for integrally geared compressors. Tracks process variables and performance. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Compressor.IntegrallyGeared.7STG.Process | Process monitoring for 7-stage integrally geared compressors. Optimized for the multi-stage process. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Compressor.Reciprocating | Template for driven reciprocating compressors. Covers the unique operational characteristics of reciprocating compressors. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Compressor.Reciprocating.Auxillary | Monitors auxiliary systems of reciprocating compressors. Focuses on supporting components like lubrication and cooling. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Compressor.Reciprocating.Mechanical | Mechanical monitoring for reciprocating compressors. Assesses vibration, cylinder condition, and other mechanical aspects. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Compressor.Reciprocating.Process | Process monitoring for reciprocating compressors. Tracks flow, pressure, and other process-related variables. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Compressor.Screw | Template for driven screw compressors. Addresses the specific design and operational features of screw compressors. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Compressor.Screw.Mechanical | Mechanical monitoring for screw compressors. Focuses on the rotating screws, bearings, and other mechanical components. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Compressor.Screw.Mechanical.Dry | Mechanical monitoring specifically for dry screw compressors. Addresses the absence of oil lubrication in the compression process. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Compressor.Screw.Mechanical.OilFlooded | Mechanical monitoring for oil-flooded screw compressors. Accounts for the presence of oil in the compression process. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Compressor.Screw.Process | Process monitoring for screw compressors. Tracks flow, pressure, and other process-related data. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Compressor.Screw.Process.Dry | Process monitoring for dry screw compressors. Optimized for the dry compression process. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Compressor.Screw.Process.OilFlooded | Process monitoring for oil-flooded screw compressors. Accounts for the presence of oil in the process. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Compressor.Screw.Process.OilFlooded.Refrigerated | Process monitoring for refrigerated, oil-flooded screw compressors. Tailored for refrigeration applications. |
#
# ##### Pump:
#
# | Template Name | Description |
# |:--|:--|
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Pump | General template for driven pumps. Covers various pump types and applications. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Pump.Centrifugal | Template for driven centrifugal pumps. A broad category covering many centrifugal pump designs. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Pump.Centrifugal.Mechanical | Mechanical monitoring for centrifugal pumps. Assesses bearings, vibrations, and other mechanical components. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Pump.Centrifugal.BetweenBearingMechanical | Specifically for between-bearing centrifugal pumps, mechanical monitoring. Focuses on the bearing arrangement. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Pump.Centrifugal.BetweenBearingProcess | Process monitoring for between-bearing centrifugal pumps. Tracks flow, pressure, and other process variables. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Pump.Centrifugal.BetweenBearingProcess.FixedSpeed | Process monitoring for fixed-speed, between-bearing centrifugal pumps. Optimized for constant-speed operation. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Pump.Centrifugal.BetweenBearingProcess.VariableSpeed | Process monitoring for variable-speed, between-bearing centrifugal pumps. Adapts to changing speed and load. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Pump.Centrifugal.LubeOilSystem | Monitors the lube oil system of a centrifugal pump. Ensures proper lubrication and cooling. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Pump.Centrifugal.Mechanical.Overhung | Mechanical monitoring for overhung centrifugal pumps. Addresses the specific design considerations of overhung pumps. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Pump.Centrifugal.Mechanical.Vertical | Mechanical monitoring for vertical centrifugal pumps. Tailored to the vertical orientation. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Pump.Centrifugal.MechanicalSeal | Monitors the mechanical seal of a centrifugal pump. Focuses on seal integrity and leakage. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Pump.Centrifugal.MechanicalSeal.Plan52 | Specifically for centrifugal pumps using API Plan 52 mechanical seals. Addresses the specific monitoring requirements. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Pump.Centrifugal.MechanicalSeal.Plan53 | Monitors centrifugal pumps using API Plan 53 mechanical seals. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Pump.Centrifugal.MechanicalSeal.Plan53.A&B | For centrifugal pumps with API Plan 53A or 53B mechanical seals. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Pump.Centrifugal.MechanicalSeal.Plan53.C | For centrifugal pumps with API Plan 53C mechanical seals. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Pump.Centrifugal.MechanicalSeal.Plan54 | For centrifugal pumps with API Plan 54 mechanical seals. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Pump.Centrifugal.MechanicalSealGas.Plan | Template for Centrifugal Pump with Gas Seal Plan. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Pump.Centrifugal.MechanicalSealSingle.Plan | Template for Centrifugal Pump with Single Seal Plan. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Pump.Centrifugal.Process | Process monitoring for centrifugal pumps. Tracks flow, pressure, and other process variables. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Pump.Centrifugal.Process.Overhung | Process monitoring for overhung centrifugal pumps. Combines process monitoring with the specific needs of overhung design. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Pump.Centrifugal.Process.Vertical | Process monitoring for vertical centrifugal pumps. Tailored to the vertical pump process. |
#
# ##### Fan:
#
# | Template Name | Description |
# |:--|:--|
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Fan | General template for driven fans. Covers various fan types and applications. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Fan.Mechanical | Mechanical monitoring for fans. Assesses bearings, vibrations, and other mechanical aspects. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Fan.Process | Process monitoring for fans. Tracks flow, pressure, and other process-related variables. |
#
# ##### Generator:
#
# | Template Name | Description |
# |:--|:--|
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Generator | General template for driven Generator. Covers various Generator types and applications. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Generator.AirCooledThermal | For Monitoring Air Cooled Thermal Generators. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Generator.Electrical | Monitoring Electrical parameters for Generators. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.Generator.Mechanical | Mechanical monitoring for Generators. Assesses bearings, vibrations, and other mechanical aspects. |
#
# ##### Torque Converter:
#
# | Template Name | Description |
# |:--|:--|
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.TorqueConvertor | General template for driven torque converters. Addresses the variable speed and torque transmission characteristics. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.TorqueConvertor.Auxillary | Monitors auxiliary systems of torque converters. Focuses on supporting components like cooling and control systems. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driven.TorqueConvertor.Mechanical | Mechanical monitoring for torque converters. Assesses the physical components and their interactions. |
#
# #### Rotating Equipment - Driver Templates
#
# These will address equipment that *powers* other machinery
#
# ##### Engine:
#
# | Template Name | Description |
# |:--|:--|
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Engine | Template for Combustion Engines |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Engine.Combustion | Template for Combustion of Engines |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Engine.Comb.Diesel | Template for Diesel Engines |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Engine.Comb.Diesel.Combustion | Monitoring and Analysis template for Diesel Combustion Engines |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Engine.Comb.Diesel.Mechanical | Monitoring and Analysis of Mechanical parameters for Diesel Combustion Engines |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Engine.Combustion.Gasoline | Template for Gasoline Engines |
#
# ##### Gearbox:
#
# | Template Name | Description |
# |:--|:--|
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Gearbox.Mechanical | Mechanical monitoring for gearboxes. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Gearbox.Mechanical.QuillShaft | Mechanical monitoring for gearboxes with quill shafts. |
#
# ##### Motor:
#
# | Template Name | Description |
# |:--|:--|
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Motor | General template for motors. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Motor.Canned.Stator.Cooling | Cooling monitoring for canned motor stators. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Motor.Mechanical | Mechanical monitoring for motors. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Motor.Thermal | Thermal monitoring for motors. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Motor.Thermal.Canned | Thermal monitoring for canned motors. |
#
# ##### Turbine:
#
# | Template Name | Description |
# |:--|:--|
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine | General template for turbines. Covers various turbine types (gas, steam). |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas | Template for gas turbines. A broad category covering various gas turbine models. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Combustion | Monitors the combustion process within a gas turbine. Focuses on fuel efficiency, emissions, and combustion stability. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Combustion.MHI501 | Specifically for Mitsubishi Heavy Industries (MHI) 501 gas turbine combustion. Tailored to the specific design and operating parameters. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Combustion.Dynamic.MHI501 | Dynamic combustion monitoring for MHI 501 gas turbines. Adapts to changing load and operating conditions. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Combustion.FT4 | For Pratt & Whitney FT4 gas turbine combustion. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Combustion.GEFrame5 | For General Electric (GE) Frame 5 gas turbine combustion. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Combustion.GEFrame6 | For GE Frame 6 gas turbine combustion. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Combustion.GEFrame7 | For GE Frame 7 gas turbine combustion. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Combustion.LM2500 | For GE LM2500 gas turbine combustion. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Combustion.RB211 | For Rolls-Royce RB211 gas turbine combustion. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Combustion.RROLYMPUS | For Rolls-Royce Olympus gas turbine combustion. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Combustion.SiemensSGT600 | For Siemens SGT-600 gas turbine combustion. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Combustion.SiemensW251 | For Siemens W251 gas turbine combustion. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Combustion.SolarCentaur40 | For Solar Centaur 40 gas turbine combustion. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Compressor | Monitors the compressor section of a gas turbine. Tracks performance and efficiency. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Compressor.FT4 | For the compressor section of a Pratt & Whitney FT4 gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Compressor.GEFrame5 | For the compressor section of a GE Frame 5 gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Compressor.GEFrame6 | For the compressor section of a GE Frame 6 gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Compressor.GEFrame7 | For the compressor section of a GE Frame 7 gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Compressor.LM2500 | For GE LM2500 gas turbine Compressor. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Compressor.MHI501 | For the compressor section of a MHI 501 gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Compressor.RB211 | For the compressor section of a Rolls-Royce RB211 gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Compressor.RROLYMPUS | For the compressor section of a Rolls-Royce Olympus gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Compressor.SiemensSGT600 | For the compressor section of a Siemens SGT-600 gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Compressor.SiemensW251 | For the compressor section of a Siemens W251 gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Compressor.SolarCentaur40 | For the compressor section of a Solar Centaur 40 gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.FuelGas | Monitors the fuel gas system of a gas turbine. Ensures proper fuel delivery and quality. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.FuelGas.FT4 | For the fuel gas system of a Pratt & Whitney FT4 gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.FuelGas.RROLYMPUS | For the fuel gas system of a Rolls-Royce Olympus gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.InletAirFilter | Monitors the inlet air filter of a gas turbine. Ensures clean air intake and prevents damage. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.LoadGear | Monitors the load gear of a gas turbine. Assesses the performance of the gearbox connecting the turbine to the driven equipment. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.LubeOilSystem | Monitors the lube oil system of a gas turbine. Ensures proper lubrication and cooling. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.LubeOilSystem.FT4 | For the lube oil system of a Pratt & Whitney FT4 gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.LubeOilSystem.GEFrame56 | For the lube oil system of GE Frame 5 and Frame 6 gas turbines. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.LubeOilSystem.GEFrame7 | For the lube oil system of a GE Frame 7 gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.LubeOilSystem.MHI501 | For the lube oil system of a MHI 501 gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.LubeOilSystem.RB211 | For the lube oil system of a Rolls-Royce RB211 gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.LubeOilSystem.RROLYMPUS | For the lube oil system of a Rolls-Royce Olympus gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.LubeOilSystem.SiemensW251 | For the lube oil system of a Siemens W251 gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.LubeOilSystem.SolarCentaur40 | For the lube oil system of a Solar Centaur 40 gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Mechanical | Monitors the mechanical aspects of a gas turbine (e.g., bearings, vibrations). |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Mechanical.FT4 | For the mechanical aspects of a Pratt & Whitney FT4 gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Mechanical.GEFrame5 | For the mechanical aspects of a GE Frame 5 gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Mechanical.GEFrame6 | For the mechanical aspects of a GE Frame 6 gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Mechanical.GEFrame7 | For the mechanical aspects of a GE Frame 7 gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Mechanical.LM2500 | For the mechanical aspects of a GE LM2500 gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Mechanical.MHI501 | For the mechanical aspects of a MHI 501 gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Mechanical.RB211.GG | For the mechanical aspects of the gas generator section of a Rolls-Royce RB211 gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Mechanical.RROLYMPUS.GG | For the mechanical aspects of the gas generator section of a Rolls-Royce Olympus gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Mechanical.RROLYMPUS.PT | For the mechanical aspects of the power turbine section of a Rolls-Royce Olympus gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Mechanical.SiemensSGT600 | For the mechanical aspects of a Siemens SGT-600 gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Mechanical.SiemensW251 | For the mechanical aspects of a Siemens W251 gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Mechanical.SolarCentaur40 | For the mechanical aspects of a Solar Centaur 40 gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Power.Mechanical | Mechanical template to analyse Power Turbine section of Gas Turbines. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Power.TurbineBladeCooling | Monitors the turbine blade cooling system of a gas turbine. Ensures proper cooling to prevent damage. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Power.TurbineBladeCooling.GEFrame5 | For the turbine blade cooling system of a GE Frame 5 gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Power.TurbineBladeCooling.GEFrame6 | For the turbine blade cooling system of a GE Frame 6 gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Power.TurbineBladeCooling.GEFrame7 | For the turbine blade cooling system of a GE Frame 7 gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.Power.TurbineBladeCooling.SiemensSGT600 | For the turbine blade cooling system of a Siemens SGT600 gas turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.TurbineBladeCooling.MHI501 | For MHI501 Gas Turbine Blade Cooling. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Gas.TurbineBladeCooling.SiemensW251 | For SiemensW251 Gas Turbine blade Cooling System. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Steam | Template for steam turbines. Covers various steam turbine types and applications. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Steam.CondensingType | For condensing type steam turbines. Addresses the specific characteristics of turbines that exhaust steam to a condenser. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Steam.CondensingType.GlandSealing | Monitors the gland sealing system of a condensing steam turbine. Prevents steam leakage and air ingress. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Steam.CondensingType.Mechanical | Mechanical monitoring for condensing steam turbines. Assesses bearings, vibrations, and other mechanical components. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Steam.CondensingType.Mechanical.MultiStage | Specifically for multi-stage condensing steam turbines, mechanical monitoring. Tailored to the multi-stage design. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Steam.CondensingType.Process | Process monitoring for condensing steam turbines. Tracks steam flow, pressure, temperature, and other process variables. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Steam.CondensingType.Process.HP | Process monitoring for the high-pressure section of a condensing steam turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Steam.CondensingType.Process.IP | Process monitoring for the intermediate-pressure section of a condensing steam turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Steam.CondensingType.Process.LP | Process monitoring for the low-pressure section of a condensing steam turbine. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Steam.MechanicalDrive | For steam turbines used in mechanical drive applications. Covers turbines directly driving other equipment. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Steam.MechanicalDrive.Mechanical | Mechanical monitoring for mechanical drive steam turbines. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Steam.MechanicalDrive.Process | Process monitoring for mechanical drive steam turbines. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Steam.MechanicalDrive.Process.BackPress | Process monitoring for back-pressure mechanical drive steam turbines. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.Steam.MechanicalDrive.Process.Condensing | Process monitoring for condensing mechanical drive steam turbines. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.TurboExpander | Template for turboexpanders. Covers expanders used to recover energy from process streams. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.TurboExpander.Amb.Mechanical | Mechanical parameters monitoring for Ambient Turbo Expanders. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.TurboExpander.GenDr.Mechanical | Mechanical template for Generator Driven Turbo Expanders. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.TurboExpander.Mechanical | Mechanical monitoring for turboexpanders. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.TurboExpander.Process | Process monitoring for turboexpanders. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.TurboExpander.Process.Compressor | Process monitoring for the compressor side of a turboexpander. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.TurboExpander.Process.Turbine | Process monitoring for the turbine side of a turboexpander. |
# | AVV-PIDT.APA.Acc.RotEqpt.Driver.Turbine.TurboExpander.Seal | Monitors the sealing system of a turboexpander. |
#
# #### Rotating Equipment - DriverDriven Templates
#
# These templates combine Driver and Driven components into a single unit for monitoring.
#
# | Template Name | Description |
# |:--|:--|
# | AVV-PIDT.APA.Acc.RotEqpt.DriverDriven | General template for combined driver and driven rotating equipment systems. |
# | AVV-PIDT.APA.Acc.RotEqpt.DriverDriven.DieselGen | Combination template for diesel engine drivers and electrical generator driven units. |
# | AVV-PIDT.APA.Acc.RotEqpt.DriverDriven.DieselGen.Combustion | Monitors the combustion process within the diesel engine of a diesel generator set. |
# | AVV-PIDT.APA.Acc.RotEqpt.DriverDriven.DieselGen.Mechanical | Monitors the mechanical aspects of both the diesel engine and generator in a diesel generator set. |
#
# ### Static Equipment Templates
#
# These templates are designed for equipment without rotating parts, focusing on process monitoring.
#
# | Template Name | Description |
# |:--|:--|
# | AVV-PIDT.APA.Acc.StatEqpt.3PhaseSeparator.APAProcess | Monitors the process parameters of a 3-phase separator. |
# | AVV-PIDT.APA.Acc.StatEqpt.AAGasSweetening.APAProcess | Monitors the process of amine absorption gas sweetening. |
# | AVV-PIDT.APA.Acc.StatEqpt.AirCooler.APAProcess | Monitors the process parameters of an air cooler. |
# | AVV-PIDT.APA.Acc.StatEqpt.AirSystem.APAProcess | Template for complete Air System. |
# | AVV-PIDT.APA.Acc.StatEqpt.ARFlashDrum.APAProcess | Monitors the process within an amine regeneration flash drum. |
# | AVV-PIDT.APA.Acc.StatEqpt.ARReclaimer.APAProcess | Monitors the process within an amine regeneration reclaimer. |
# | AVV-PIDT.APA.Acc.StatEqpt.ARRefluxDrum.APAProcess | Monitors the process within an amine regeneration reflux drum. |
# | AVV-PIDT.APA.Acc.StatEqpt.ARRichLeanHEXPlate.APAProcess | Monitors a plate-type heat exchanger in an amine regeneration system (rich/lean). |
# | AVV-PIDT.APA.Acc.StatEqpt.ARRichLeanHEXTube.APAProcess | Monitors a shell-and-tube heat exchanger in an amine regeneration system (rich/lean). |
# | AVV-PIDT.APA.Acc.StatEqpt.ARStripperReboiler.APAProcess | Monitors the process within an amine regeneration stripper reboiler. |
# | AVV-PIDT.APA.Acc.StatEqpt.BDColumnReboilerCondenserTray.APAProcess | Template for BD Column, Reboiler, Condenser and Tray. |
# | AVV-PIDT.APA.Acc.StatEqpt.ChillerDistributionBufferTank.APAProcess | Template for Chiller Distribution and Buffer Tank. |
# | AVV-PIDT.APA.Acc.StatEqpt.ChillerEvaporator.APAProcess | Monitors the process within a chiller evaporator. |
# | AVV-PIDT.APA.Acc.StatEqpt.CompressorProcessScrubber.APAProcess | Monitors the process within a compressor process scrubber. |
# | AVV-PIDT.APA.Acc.StatEqpt.CompressorSuctionFilter.APAProcess | Monitors the process and condition of a compressor suction filter. |
# | AVV-PIDT.APA.Acc.StatEqpt.CondCollectionVessel.APAProcess | Monitors the process parameters of a condensate collection vessel. |
# | AVV-PIDT.APA.Acc.StatEqpt.CondSplitter.APAProcess | Monitors the process within a condensate splitter. |
# | AVV-PIDT.APA.Acc.StatEqpt.CondStripper.APAProcess | Monitors the process within a condensate stripper. |
# | AVV-PIDT.APA.Acc.StatEqpt.CrudeStabilizationColumn.APAProcess | Monitors the process within a crude stabilization column. |
# | AVV-PIDT.APA.Acc.StatEqpt.Deaerator.APAProcess | Monitors the process parameters of a deaerator vessel. |
# | AVV-PIDT.APA.Acc.StatEqpt.Dehydrator.APAProcess | Monitors the process within a dehydrator. |
# | AVV-PIDT.APA.Acc.StatEqpt.Demethaniser.APAProcess | Monitors the process within a demethaniser. |
# | AVV-PIDT.APA.Acc.StatEqpt.Desalter.APAProcess | Process parameters monitoring for Desalter. |
# | AVV-PIDT.APA.Acc.StatEqpt.DMHeatExchanger.APAProcess | Template for DM Heat Exchanger. |
# | AVV-PIDT.APA.Acc.StatEqpt.FlareSealDrum.APAProcess | Monitors the process within a flare seal drum. |
# | AVV-PIDT.APA.Acc.StatEqpt.FuelGasSystem.APAProcess | Monitors the process parameters of a fuel gas system. |
# | AVV-PIDT.APA.Acc.StatEqpt.GasDehydrationColumn.APAProcess | Monitors the process within a gas dehydration column. |
# | AVV-PIDT.APA.Acc.StatEqpt.GlycolExpansionTank.APAProcess | Monitors the process within a glycol expansion tank. |
# | AVV-PIDT.APA.Acc.StatEqpt.GlycolFlashDrum.APAProcess | Monitors the process within a glycol flash drum. |
# | AVV-PIDT.APA.Acc.StatEqpt.GlycolHeatingMediumSumpDrum.APAProcess | Monitors the process within a glycol heating medium sump drum. |
# | AVV-PIDT.APA.Acc.StatEqpt.GRCondAirCooler.APAProcess | Monitors the process within a glycol regeneration condenser and air cooler. |
# | AVV-PIDT.APA.Acc.StatEqpt.GRDistillationReboiler.APAProcess | Monitors the process within a glycol regeneration distillation and reboiler. |
# | AVV-PIDT.APA.Acc.StatEqpt.GRFlashDrum.APAProcess | Monitors the process within a glycol regeneration flash drum. |
# | AVV-PIDT.APA.Acc.StatEqpt.GRRefluxDrum.APAProcess | Monitors the process within a glycol regeneration reflux drum. |
# | AVV-PIDT.APA.Acc.StatEqpt.GRRichLeanHEX.APAProcess | Monitors a heat exchanger in a glycol regeneration system (rich/lean). |
# | AVV-PIDT.APA.Acc.StatEqpt.GRRichLeanHEXPlate.APAProcess | Template for Glycol Regeneration Plate type Rich/Lean Heat Exchanger. |
# | AVV-PIDT.APA.Acc.StatEqpt.GRSurgeDrum.APAProcess | Monitors the process within a glycol regeneration surge drum. |
# | AVV-PIDT.APA.Acc.StatEqpt.HeatExchanger.APAProcess | Monitors the process parameters of a general heat exchanger. |
# | AVV-PIDT.APA.Acc.StatEqpt.HeatExchangerPlateType.APAProcess | Monitors the process parameters of a plate-type heat exchanger. |
# | AVV-PIDT.APA.Acc.StatEqpt.HeatingMediumCombustion.APAProcess | Monitors the combustion process within a heating medium system. |
# | AVV-PIDT.APA.Acc.StatEqpt.HeatingMediumProcess.APAProcess | Monitors the process side of a heating medium system. |
# | AVV-PIDT.APA.Acc.StatEqpt.HeatlessDessicantDryer.APAProcess | Monitors the process within a heatless desiccant dryer. |
# | AVV-PIDT.APA.Acc.StatEqpt.KnockOutDrumWithoutPump.APAProcess | Monitors the process within a knock-out drum without a pump. |
# | AVV-PIDT.APA.Acc.StatEqpt.KnockOutDrumWithPump.APAProcess | Monitors the process within a knock-out drum with a pump. |
# | AVV-PIDT.APA.Acc.StatEqpt.KODDrainPump.APAProcess | Monitors the KOD Drain Pump. |
# | AVV-PIDT.APA.Acc.StatEqpt.LPStripper.APAProcess | Monitors the process within an LP stripper. |
# | AVV-PIDT.APA.Acc.StatEqpt.N2GenerationMembrane.APAProcess | Monitors the process of N2 generation using a membrane system. |
# | AVV-PIDT.APA.Acc.StatEqpt.N2GeneratorPSA.APAProcess | Template for N2 Generator of PSA type. |
# | AVV-PIDT.APA.Acc.StatEqpt.OilStabilizationColumn.APAProcess | Monitors the process within an oil stabilization column. |
# | AVV-PIDT.APA.Acc.StatEqpt.ProducedWaterDegasser.APAProcess | Monitors the process within a produced water degasser. |
# | AVV-PIDT.APA.Acc.StatEqpt.RefineryStorageTank.APAProcess | Monitors the process parameters of a refinery storage tank. |
# | AVV-PIDT.APA.Acc.StatEqpt.RODesalination.APAProcess | Template for RO Desalination Unit. |
# | AVV-PIDT.APA.Acc.StatEqpt.SeperatorFilter.APAProcess | Monitors the process within a separator with a filter (e.g., flue gas). |
# | AVV-PIDT.APA.Acc.StatEqpt.SlugCatcher.APAProcess | Monitors the process within a slug catcher. |
# | AVV-PIDT.APA.Acc.StatEqpt.SuctionDrum.APAProcess | Monitors the process within a suction drum. |
# | AVV-PIDT.APA.Acc.StatEqpt.Transformer.APAProcess | Monitors the process parameters of an electrical transformer. |
# | AVV-PIDT.APA.Acc.StatEqpt.WHRU.APAProcess | Template for Waste Heat Recovery Unit. |
